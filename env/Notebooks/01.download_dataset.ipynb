# %%
import numpy as np

# %%
import json
with open('../artifacts/kaggle.json', 'r') as file:
    kaggle_creds = json.load(file)

# %%
kaggle_creds
# Out:
# {'username': 'amanthasanuja', 'key': 'badf6d317af7841c3b98339b35a15ed8'}

# %%
# %pip install kaggle
# Out:
# Requirement already satisfied: kaggle in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (1.8.3)
# Requirement already satisfied: black>=24.10.0 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (26.1.0)
# Requirement already satisfied: bleach in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (0.1.15)
# Requirement already satisfied: mypy>=1.15.0 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: packaging in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (26.0)
# Requirement already satisfied: protobuf in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (6.33.5)
# Requirement already satisfied: python-dateutil in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: six>=1.10 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (4.67.2)
# Requirement already satisfied: types-requests in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (2.32.4.20260107)
# Requirement already satisfied: types-tqdm in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from kaggle) (2.6.3)
# Requirement already satisfied: click>=8.0.0 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from black>=24.10.0->kaggle) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from black>=24.10.0->kaggle) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from black>=24.10.0->kaggle) (1.0.4)
# Requirement already satisfied: platformdirs>=2 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from black>=24.10.0->kaggle) (4.5.1)
# Requirement already satisfied: pytokens>=0.3.0 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from black>=24.10.0->kaggle) (0.4.1)
# Requirement already satisfied: colorama in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from click>=8.0.0->black>=24.10.0->kaggle) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Requirement already satisfied: librt>=0.6.2 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from mypy>=1.15.0->kaggle) (0.7.8)
# Requirement already satisfied: webencodings in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in e:\IIT\IIT - 4th year\FYP\Smart-Phones-Feature-Recommendation-System-using-user-reviews\env\Lib\site-packages (from requests->kaggle) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['KAGGLE_USERNAME'] = kaggle_creds['username']
os.environ['KAGGLE_KEY'] = kaggle_creds['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()
api.dataset_download_files('codewithuday/amazon-phone-product-reviews-and-rating-2024', path='../artifacts/', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/codewithuday/amazon-phone-product-reviews-and-rating-2024
